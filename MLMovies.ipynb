# %% [markdown]
# ## Importing needed data

# %%
from sklearn.model_selection import train_test_split
from numpy import* 
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Loading and splitting the data

# %%
df = pd.read_csv('/kaggle/input/imdb-dataset-of-50k-movie-reviews/IMDB Dataset.csv')
x = df['review']
y = df['sentiment'] 
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print("Number of samples in training data:", x_train.shape[0])
print("Number of samples in training data:", y_test.shape[0])
# Out:
# Number of samples in training data: 40000
# Number of samples in training data: 10000

# %% [markdown]
# ## Training the model

# %%
pipeline = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', LogisticRegression(max_iter=200)),
])
pipeline.fit(x_train, y_train)
y_pred=pipeline.predict(x_train)
accuracy = accuracy_score(y_train, y_pred)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.93195

# %% [markdown]
# ## Testing the model

# %%
y_pred_test=pipeline.predict(x_test)
#print(y_pred_test)
#print(y_test)
#print(x_test)
accuracy_test=accuracy_score(y_test, y_pred_test)
print("Accuracy: ", accuracy_test)
# Out:
# Accuracy:  0.9003

# %% [markdown]
# ## Testing the model myself

# %%
df1 = pd.read_csv('/kaggle/input/weiiiird/testing_Ayoub.txt')
predicted_label = pipeline.predict(df1)
print("Predicted label:", predicted_label)
# Out:
# Predicted label: ['negative']
